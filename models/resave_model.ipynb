# %%
import joblib

model = joblib.load('engine_maintenance_model.pkl')

joblib.dump(model, 'engine_maintenance_model_v2.pkl')
# Out:
# ['engine_maintenance_model_v2.pkl']

# %% [markdown]
# The trained model was re-serialized in a controlled environment to ensure compatibility between training and deployment stages, avoiding binary incompatibility issues.
